# %%
import pandas as pd

df = pd.read_csv("../data/processed/cicids2017_friday_ddos_cleaned.csv")

# %% [markdown]
# ### Feature Analysis
#
# This stage focuses on understanding the statistical behaviour, scale, and relevance of features in the cleaned network traffic dataset, with particular attention to differences between benign and DDoS flows.

# %%
df.shape
# Out:
# (223080, 79)

# %%
df[" Label"].value_counts()
# Out:
#  Label
# DDoS      128014
# BENIGN     95066
# Name: count, dtype: int64

# %% [markdown]
# The dataset contains both benign and DDoS traffic, enabling supervised analysis of feature behaviour across classes.

# %%
num_df = df.select_dtypes(include="number")
num_df.shape
# Out:
# (223080, 78)

# %% [markdown]
# Statistical values
# - Analysis is restricted to numerical features, as these directly influence model learning and distance-based behaviour.

# %%
df.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count      223080.000000    2.230800e+05       223080.000000
# mean         8979.459248    1.643558e+07            4.905841
# std         19844.840946    3.166184e+07           15.510815
# min             0.000000    1.000000e+00            1.000000
# 25%            80.000000    8.179200e+04            2.000000
# 50%            80.000000    1.537970e+06            3.000000
# 75%            80.000000    8.958845e+06            5.000000
# max         65532.000000    1.199999e+08         1932.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count            223080.000000                223080.000000
# mean                  4.612166                   949.798010
# std                  21.881669                  3267.295982
# min                   0.000000                     0.000000
# 25%                   1.000000                    26.000000
# ...

# %% [markdown]
# Skew and Scale
#
# - Network traffic features show uneven distributions, with many small values and a few extremely large ones. Feature ranges also vary widely across columns, which is typical for real-world DDoS traffic.

# %%
num_df.nunique().sort_values().head(20)
# Out:
#  Bwd PSH Flags           1
#  Fwd Avg Bulk Rate       1
# Bwd Avg Bulk Rate        1
#  Bwd Avg Packets/Bulk    1
#  Bwd Avg Bytes/Bulk      1
# Fwd Avg Bytes/Bulk       1
#  Bwd URG Flags           1
#  Fwd Avg Packets/Bulk    1
#  CWE Flag Count          1
#  Fwd URG Flags           1
#  RST Flag Count          2
# Fwd PSH Flags            2
#  ACK Flag Count          2
#  PSH Flag Count          2
#  URG Flag Count          2
#  SYN Flag Count          2
#  ECE Flag Count          2
# FIN Flag Count           2
#  Down/Up Ratio           8
#  min_seg_size_forward    8
# dtype: int64

# %% [markdown]
# Several numerical features exhibit no variability across the dataset, indicating near-constant behaviour and limited usefulness for classification.
